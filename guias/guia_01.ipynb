# %% [markdown]
# <a href="https://colab.research.google.com/github/EbnerLautaro/Redes-Neuronales/blob/main/practicos/practico_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Familiarizandose con **Google Colab** y **Python**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Ejercicio 13)** Graficando

# %% [markdown]
# ### **1)** Utilice `np.linspace` para generar un array de 100 valores equidistantes entre 0 y 5. Almacene el array en una variable `valores_x`.

# %%
# 13.1)
valores_x = np.linspace(start=0, stop=5, num=100)

# %% [markdown]
# ### **2)** Calcule el array llamado `valores_y1` de valores `np.cos(x)` para cada `x` en `valores_x`.

# %%
valores_y1 = [np.cos(x) for x in valores_x]

# %% [markdown]
# ### **3)** Calcule el array llamado `valores_y2` de valores `np.sin(x)` para cada `x` en `valores_x`.

# %%
valores_y2 = [np.sin(x) for x in valores_x]

# %% [markdown]
# ### **4)** Use estos arrays para graficar, con curvas, las funciones $\cos(x)$ y $\sin(x)$ en el rango $[0,5]$. Use una línea contínua para el coseno y una punteada para el seno.

# %%
fig, ax = plt.subplots()
ax.plot(valores_x, valores_y1)
ax.plot(valores_x, valores_y2, linestyle='dashed', color="red")

# %% [markdown]
# ### **5)** Acomode el gráfico: agregue etiquetas a los ejes y a las curvas. Modifique los límites del área graficada para que se vean correctamente las curvas. Agregue un título a la figura.

# %%
fig, ax = plt.subplots()
ax.plot(valores_x, valores_y1, linestyle="-", color="blue", label="cos(x)")
ax.plot(valores_x, valores_y2, linestyle="--", color="orange", label="sin(x)")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.title("Seno y Coseno")
plt.legend()
plt.show()
